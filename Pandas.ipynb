# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# Series = one Dimention,

# %%
l = [2,43,21,83,19,32]

series = pd.Series(l)
series
# Out:
# 0     2
# 1    43
# 2    21
# 3    83
# 4    19
# 5    32
# dtype: int64

# %%
type(series)
# Out:
# pandas.Series

# %%
dict = {'a':2,'b':43,'c':21,'d':83,'e':19,'f':32}

res = pd.Series(dict)
res
# Out:
# a     2
# b    43
# c    21
# d    83
# e    19
# f    32
# dtype: int64

# %%
for i in res:
    print(i)
# Out:
# 2
# 43
# 21
# 83
# 19
# 32

# %%
res['a']
# Out:
# np.int64(2)

# %%
res['a' : 'd']
# Out:
# a     2
# b    43
# c    21
# d    83
# dtype: int64

# %% [markdown]
# Dataframe = more than one Dimention (usually 2d)

# %%
data = [["abc",1],['def',2],['ghi',3],['hij'],['kim',5]]
data_df = pd.DataFrame(data)
data_df
# Out:
#      0    1
# 0  abc  1.0
# 1  def  2.0
# 2  ghi  3.0
# 3  hij  NaN
# 4  kim  5.0

# %%
data_df.columns = ['Alphabhet','Numbers']

# %%
data_df
# Out:
#   Alphabhet  Numbers
# 0       abc      1.0
# 1       def      2.0
# 2       ghi      3.0
# 3       hij      NaN
# 4       kim      5.0

# %%
data_df.columns
# Out:
# Index(['Alphabhet', 'Numbers'], dtype='str')

# %%
data_df.rename({'Alphabhet' : 'Alpha'} , axis = 1 , inplace= True )

# %%
data_df
# Out:
#   Alpha  Numbers
# 0   abc      1.0
# 1   def      2.0
# 2   ghi      3.0
# 3   hij      NaN
# 4   kim      5.0

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q
