# %% [markdown]
# # Demo

# %% [markdown]
# ## Day 1 of Python

# %%
print("Hello World")
# Out:
# Hello World

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
a = 5
A1 = 3
# Adding 2 numbers 
print(a + A1)
# Out:
# 8

# %%
''' 
This is Multi Line Comment  
example of multi line Comment 
'''
# Out:
# ' \nThis is Multi Line Comment  \nexample of multi line Comment \n'

# %%
# Multi line Execution 
Result = 12+34+87 \
+23+34+72+23 \
+24+57+47+63+24+58+97 
print(Result)
# Out:
# 655

# %%
int_var = 5 # Integer ( positive or negative numbers )
float_var = 9.234 # Float ( Any Decimal Numbers Positive or negative )
string_var = 'name' 
print( int_var,'\n',float_var,'\n',string_var)
# Out:
# 5
#  9.234
#  name

# %%
a = '5'
b = '1'
c = a + b
print(c) # the result is 51 because we are adding strings not numbers 
print('-----------------------------')
c = 4 
d = 56.234
print(c + d ) # the Result is 60.234 because the variables are in int and float which supports math operation
# Out:
# 51
# -----------------------------
# 60.234

# %%
print(type(A1))
# Out:
# <class 'int'>

# %%
from datetime import datetime
date = datetime.now()
print(type(date))
# Out:
# <class 'datetime.datetime'>

# %%
import numpy as np 
a = np.array([1,456,78,789,34,2,3265,42,134,21])
print(type(a))
# Out:
# <class 'numpy.ndarray'>

# %%
# !pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.3 MB 4.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.8/12.3 MB 4.4 MB/s eta 0:00:03
#    ------ --------------------------------- 2.1/12.3 MB 4.4 MB/s eta 0:00:03
#    --------- ------------------------------ 2.9/12.3 MB 3.3 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.4/12.3 MB 3.2 MB/s eta 0:00:03
#    ------------- -------------------------- 4.2/12.3 MB 3.4 MB/s eta 0:00:03
#    --------------- ------------------------ 4.7/12.3 MB 3.3 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.5/12.3 MB 3.3 MB/s eta 0:00:03
#    ------------------ --------------------- 5.8/12.3 MB 2.9 MB/s eta 0:00:03
#    -------------------- ------------------- 6.3/12.3 MB 2.9 MB/s eta 0:00:03
# ...

# %%
date= '01-01-2026'
print(type(date))
# Out:
# <class 'str'>

# %% [markdown]
# ### Boolean

# %%
var = True 
flag = False
print(type(var), ',',var, ',' ,type(var))
# Out:
# <class 'bool'> , True , <class 'bool'>

# %% [markdown]
# string Indexing

# %%
name = "Hello World"
print(name[9])
print(len(name) -1)
# Out:
# l
# 10

# %% [markdown]
# string sclicing

# %%
name[0 : 5]  # variable[ start index : end index ] note end index will be excluded
# Out:
# 'Hello'

# %%
name[-5 : -1] # this is negative indexing counting backwords with negative sign
# Out:
# 'Worl'

# %% [markdown]
# name = "Hello World"

# %%
name[0 : len(name) : 2] # variable[ start index : end index : step/jump size ]
# Out:
# 'HloWrd'

# %%
name[: : -1 ]
# Out:
# 'dlroW olleH'

# %%
name[len(name) -1 :  : -2]
# Out:
# 'drWolH'

# %%
print(name[ : 10 ]) # by default the start index will be zero
print(name[3 : ]) # by default it will print till last index
# Out:
# Hello Worl
# lo World

# %% [markdown]
# Updating and Deleting the Strings

# %%
course = 'Data Science'
course[:4]
# Out:
# 'Data'

# %%
course[:4] = 'Life'
course

# %%
course = course.replace('Data', 'Life')

# %%
course
# Out:
# 'Life Science'

# %%
del course

# %%
course
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 course
#
# NameError: name 'course' is not defined

# %% [markdown]
# String Concatination

# %%
s1 = 'Hello'
s2 = 'World'
s3 = s1 + '_' +s2
print(s3)
# Out:
# Hello_World

# %% [markdown]
# String Membership

# %%
name = 'this is python class'
print('python' in name)
print('Class' in name)
# Out:
# True
# False

# %%
str5 = "Natural language processing with Python and R and Java"
L = str5.partition("and") # Divides strings if it finds that specific world (only for first occorances )
L
# Out:
# ('Natural language processing with Python ', 'and', ' R and Java')

# %%
str5.count('a')
# Out:
# 8

# %%
greet = '    Hello Good                       Morning    ' 
print(greet)
print(greet.strip())
# Out:
#     Hello Good                       Morning
# Hello Good                       Morning

# %%
res = greet.split()
print(res)
# Out:
# ['Hello', 'Good', 'Morning']

# %%
r = ''

# %%
for i in res:
    r += i + ' '
r.strip()
# Out:
# 'Hello Good Morning'

# %%
prep='   &&&&   ***Preparation Predecessor & Premonition Prenuptials Projection*****   %%&&&'
prep
# Out:
# '   &&&&   ***Preparation Predecessor & Premonition Prenuptials Projection*****   %%&&&'

# %%
prep.strip("& %*")
# Out:
# 'Preparation Predecessor & Premonition Prenuptials Projection'

# %% [markdown]
# how can we remove all special characters from string?

# %%
import re

text = "Hello@# World! 123"
clean = re.sub(r'[^a-zA-Z0-9]', ' ', text)

print(clean)
# Out:
# Hello   World  123

# %%
import string
string.punctuation
result =''
for i in prep:
    if i not in  string.punctuation:
        result += i

# %%
result
# Out:
# '      Preparation Predecessor  Premonition Prenuptials Projection   '

# %%
result.lower()
# Out:
# '      preparation predecessor  premonition prenuptials projection   '

# %%
result.upper()
# Out:
# '      PREPARATION PREDECESSOR  PREMONITION PRENUPTIALS PROJECTION   '

# %% [markdown]
# String Formating

# %%
item1 = 432
item = 23
total = item +item1
print("Total bill is {} only ".format(total))
print(f"Total Bill is {total:.4f}") # F string
# Out:
# Total bill is 455 only
# Total Bill is 455.0000

# %% [markdown]
# Typecasting

# %%
# auto type casting 
4 + 5.24 + False + True
# Out:
# 10.24

# %%
3 + 43.38765 + '4'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 3 + 43.38765 + '4'
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
# Forced type casting 
string_ = '-5'
num = 1
float_ = 3.34

sum = float_ + num + abs(float(string_))
print(sum)
# Out:
# 869.34

# %%
print(bool(0.1), bool(0), bool(0.1), bool(2))
# Out:
# True False True True
